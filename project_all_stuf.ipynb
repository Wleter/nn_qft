# %%
#Color printing
from termcolor import colored

#General data operations library
import math, string, glob
from datetime import datetime
import numpy as np
import numpy.typing as npt
import functools

#The tensorflow library
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"
import tensorflow  as tf
import tensorflow_datasets as tfds

#Plotting libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
from collections import Counter

#Increase plots font size
params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (10, 7),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

#append path with python modules
import importlib

from dataclasses import dataclass
from modules import metropolis as metro
importlib.reload(metro)
from modules import qft_problem
importlib.reload(qft_problem)
from modules.hamiltonians import hamiltonian_terms
importlib.reload(hamiltonian_terms)
import modules.ansatz_nn as ansatz_nn
importlib.reload(ansatz_nn)
import modules.hamiltonians.lieb_liniger_model as ll_model
importlib.reload(ll_model)
import modules.plots as plots
importlib.reload(plots)
# Out:
# <module 'modules.plots' from 'c:\\Users\\marcr\\Documents\\vs_code\\nn_qft\\modules\\plots.py'>

# %% [markdown]
# # Data generation

# %% [markdown]
# We have some many-body system with the Hamiltonian $H$ and we want to find its ground state. We use variational principle to find the ground energy of the system. Given the n particle positions $x_n$ the neural network calculate the $\varphi_n(x_n)$ wave function amplitude for given configuration.

# %% [markdown]
# To estimate the ground state energy we use monte carlo integration techinique, with sampling the configurations according to our current neural network model.
# To do that we use metropolis algorithm. This means that our data generation is coupled to the current model.

# %% [markdown]
# As to demonstrate the data generation we create a test problem in 2d, with wave function that is exponentially decaying with number of particles times $(n + 0.1)$ times the product of sinuses in first and second dimension. We then create the dataset from generator that uses metropolis algorithm to create next steps on our test model. We see the distribution of configurations is the estimation of the test problem.

# %%
@dataclass
class TestProblem(qft_problem.QFTProblem):
    size: tuple[float, float] = (10, 100)

    def volume(self) -> npt.NDArray:
        return np.array(self.size)

    def get_amplitude(self, x_n: tf.Tensor, ns: npt.NDArray, training: bool = False) -> tf.Tensor:
        mask = tf.sequence_mask(ns, maxlen = x_n.shape[-2])

        mask = tf.cast(mask, x_n.dtype)
        masked_sin = tf.where(mask > 0, tf.sin(x_n[:, :, 0]) * tf.sin(x_n[:, :, 1] / 20), tf.ones_like(x_n[:, :, 0])) # type: ignore
        profile = tf.pow(tf.reduce_prod(masked_sin, axis=1), 2)

        ns = tf.cast(ns, x_n.dtype) # type: ignore

        return profile * np.exp(-ns / 10.) / np.power(np.prod(self.volume()), ns / 2.) * (0.1 + ns)

# %%
batch = 1
n_max = 10

test_problem = TestProblem()
test_metropolis = metro.FockSpaceMetropolis(test_problem, n_max, rng=np.random.default_rng(0))

def metropolis_step(metropolis: metro.FockSpaceMetropolis, batch = 32, n_init = 5):
    x_recent, amplitude_recent = metropolis.new_configuration(batch, n_init)
    while True:
        x_recent, amplitude_recent = metropolis.step(x_recent, amplitude_recent)
        yield x_recent.x_n, x_recent.n_s

dataset = tf.data.Dataset.from_generator(
    lambda: metropolis_step(test_metropolis, batch = batch),
    output_signature = (
        tf.TensorSpec(shape=(batch, n_max, 2), dtype=tf.float32, name="configuration"), # type: ignore
        tf.TensorSpec(shape=(batch), dtype=tf.int32, name = "particle_no") # type: ignore
    )
)

# %%
fig, axes = plots.plot_metropolis_samples(dataset.unbatch().skip(3000).take(7000), dim = 2);

# %%
tfds.benchmark(dataset.take(1000), batch_size = 32)
# Out:
# ************ Summary ************
# 0it [00:00, ?it/s]
# Examples/sec (First included) 25893.55 ex/sec (total: 32032 ex, 1.24 sec)
# Examples/sec (First only) 1114.50 ex/sec (total: 32 ex, 0.03 sec)
# Examples/sec (First excluded) 26482.35 ex/sec (total: 32000 ex, 1.21 sec)
# BenchmarkResult(stats=             duration  num_examples           avg
# first+lasts  1.237065         32032  25893.554791
# first        0.028712            32   1114.501052
# lasts        1.208352         32000  26482.345131, raw_stats=                      duration
# start_time        29506.051190
# first_batch_time  29506.079903
# end_time          29507.288255
# num_iter           1000.000000)

# %% [markdown]
# # Model architecture and learning

# %% [markdown]
# In our problem, we train the neural network using training data generated by the Metropolis algorithm from the given system configuration. To perform training, we must generate new training data separately for each training session. This is necessary because the training process involves minimizing the energy of the system, and the Metropolis algorithm generates a set of sample points $ x_n $ that are distributed according to the probability distribution corresponding to the current state of the system.
#
# In the Deep Sets architecture that we use to represent the state of the system, we do not implement the network as a traditional sequence of connected layers. Instead, we define several models and compose their outputs.
#
# The state of the system is represented as
#
# $$|\Psi\rangle = \bigoplus_{n=0}^{\infty} \varphi_n(x_n),$$
#
# where each $ \varphi_n $ is a symmetric function that takes $ n $ positions as its arguments. This structure suggests that the neural network, interpreted as a (wave)function $f : \mathbb{R}^N \rightarrow \mathbb{C} $, should have an architecture reflecting the decomposition
#
# $$f(x_N) = \rho_1 \left( \sum_{x \in x_N} \phi_1(x) \right) \cdot \rho_2 \left( \sum_{x_i < x_j \in x_N} \phi_2(x_i - x_j) \right),$$
#
# where $ N $ is a cutoff on the number of particles considered, and $ \rho_1 $, $ \rho_2 $ and $ \phi_1 $, $ \phi_2 $ are usual DNN.

# %% [markdown]
# # Lieb-Liniger theory

# %% [markdown]
# Lieb-Liniger theory is quantum field theory used in the theory of cold gases. It represents contact interactions (via δ-function), so it is analogous to more familiar ϕ^4 theory. The Hamiltonian of that theory is:
#
# \begin{equation}
# H_{\text{LL}} = \frac{1}{2m} \int dx \, \frac{d \hat{\psi}^\dagger(x)}{dx} \frac{d \hat{\psi}(x)}{dx}
# - \mu \int dx \, \hat{\psi}^\dagger(x) \hat{\psi}(x)
# + g \int dx \, \hat{\psi}^\dagger(x) \hat{\psi}^\dagger(x) \hat{\psi}(x) \hat{\psi}(x).
# \end{equation}
#
# We have included the chemical potential in the Hamiltonian.
# The contact interaction between particles is not implemented through an additional term in the energy (loss) function of the model, due to the difficulty of approximating such a singular object.
# Instead, we multiply the output of the network by a so-called Jastrow factor (as also done by the authors of the cited paper):
#
#
# \begin{equation}
# J_n^{\text{LL}}(\mathbf{x}_n) = \prod_{i < j}^{n} \left( \frac{1}{L} |x_i - x_j| + \frac{1}{mgL} \right).
# \end{equation}
#
# This prescription ensures that the wavefunction vanishes when two or more particles coincide.
# At the end of each neural network evaluation, we also multiply the output by a regularization factor that constrains the number of particles to lie within a finite window.
# The parameters controlling the width of this window are also trainable. Regularisation factor takes the form:
#
# \begin{equation}
# \left( \frac{1}{1 + e^{-\alpha(n - q_1)}} \right) \left( \frac{1}{1 + e^{\alpha(n - q_2)}} \right)
# \end{equation}
#
# In case of "hard wall" boundary conditions, output of the network is also multiplied by a "cutoff factor" that imposes them:
#
# \begin{equation}
# \left( \frac{L}{30} \right)^{-n/2} \prod_{i=1}^{n} \frac{x_i}{L} \left( 1 - \frac{x_i}{L} \right),
# \end{equation}

# %% [markdown]
# ## Lieb-Liniger, with $m = 0.5$, $\mu = (3.75 \pi)^2$, $g = 10^6$

# %%
from modules.ansatz_nn import ParticleNoReg


input_dim = 1
batch_size = 64

ds1 = ansatz_nn.DeepSets(64, 2, 2, input_dim=input_dim, name = "deep_set_1")
ds2 = ansatz_nn.DeepSets(64, 2, 2, input_dim=input_dim, name = "deep_set_2")

hamiltonian = ll_model.LiebLinigerHamiltonian(0.5, (3.75 * np.pi) ** 2, 1e6)

test_model = ansatz_nn.QFTNeuralNet(
    np.array([1]),
    ds1,
    ds2,
    hamiltonian,
    is_periodic = False,
    regularization = ParticleNoReg(2., 0.3, 0.3),
)

dataset = metro.make_dataset(test_model, batch_size, 10, 5)

# %%
tfds.benchmark(dataset.take(1000), batch_size = batch_size)
# Out:
# ************ Summary ************
# 0it [00:00, ?it/s]
# Examples/sec (First included) 5036.08 ex/sec (total: 64064 ex, 12.72 sec)
# Examples/sec (First only) 683.77 ex/sec (total: 64 ex, 0.09 sec)
# Examples/sec (First excluded) 5068.35 ex/sec (total: 64000 ex, 12.63 sec)
# BenchmarkResult(stats=              duration  num_examples          avg
# first+lasts  12.720993         64064  5036.084880
# first         0.093599            64   683.765067
# lasts        12.627394         64000  5068.346053, raw_stats=                      duration
# start_time        30079.073744
# first_batch_time  30079.167344
# end_time          30091.794737
# num_iter           1000.000000)

# %%
fig, axes = plots.plot_metropolis_samples(dataset.skip(500).unbatch().take(7000));

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    1e-2,
    decay_steps = 25,
    decay_rate = 0.9,
    staircase=True
)

test_model.compile(
    optimizer = tf.keras.optimizers.Adam(lr_schedule),
    regularization_lr_modifier = 100
)

history = test_model.fit(
    dataset.skip(500).take(1000),
    epochs = 200,
)
# Out:
# Epoch 1/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - energy: -125.7321 - loss: -125.7321 - mean_particle_number: 1.0128
# Epoch 2/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -134.9626 - loss: -134.9626 - mean_particle_number: 1.1096
# Epoch 3/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -150.9738 - loss: -150.9738 - mean_particle_number: 1.2968
# Epoch 4/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -186.6656 - loss: -186.6656 - mean_particle_number: 1.6871
# Epoch 5/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -209.9405 - loss: -209.9405 - mean_particle_number: 2.0729
# Epoch 6/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -225.0051 - loss: -225.0051 - mean_particle_number: 2.3588
# Epoch 7/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -227.8224 - loss: -227.8224 - mean_particle_number: 2.4663
# Epoch 8/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -240.7292 - loss: -240.7292 - mean_particle_number: 2.5657
# Epoch 9/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -242.4695 - loss: -242.4695 - mean_particle_number: 2.5924
# Epoch 10/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -237.9259 - loss: -237.9259 - mean_particle_number: 2.6029
# Epoch 11/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -251.7035 - loss: -251.7035 - mean_particle_number: 2.6293
# Epoch 12/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -252.6774 - loss: -252.6774 - mean_particle_number: 2.6279
# Epoch 13/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -236.5663 - loss: -236.5663 - mean_particle_number: 2.6555
# Epoch 14/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -247.2912 - loss: -247.2912 - mean_particle_number: 2.6362
# Epoch 15/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -239.1854 - loss: -239.1854 - mean_particle_number: 2.6427
# Epoch 16/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -231.7900 - loss: -231.7900 - mean_particle_number: 2.6433
# Epoch 17/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -262.9733 - loss: -262.9733 - mean_particle_number: 2.6665
# Epoch 18/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -225.8665 - loss: -225.8665 - mean_particle_number: 2.6506
# Epoch 19/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -243.1340 - loss: -243.1340 - mean_particle_number: 2.6637
# Epoch 20/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -245.4873 - loss: -245.4873 - mean_particle_number: 2.6708
# Epoch 21/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -261.2898 - loss: -261.2898 - mean_particle_number: 2.6627
# Epoch 22/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -246.5237 - loss: -246.5237 - mean_particle_number: 2.6732
# Epoch 23/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -227.8326 - loss: -227.8326 - mean_particle_number: 2.6689
# Epoch 24/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -245.2798 - loss: -245.2798 - mean_particle_number: 2.6644
# Epoch 25/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -250.2594 - loss: -250.2594 - mean_particle_number: 2.6700
# Epoch 26/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -266.9788 - loss: -266.9788 - mean_particle_number: 2.6746
# Epoch 27/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -235.4303 - loss: -235.4303 - mean_particle_number: 2.6811
# Epoch 28/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -250.4451 - loss: -250.4451 - mean_particle_number: 2.6661
# Epoch 29/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - energy: -219.7949 - loss: -219.7949 - mean_particle_number: 2.6983
# Epoch 30/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -231.7791 - loss: -231.7791 - mean_particle_number: 2.6980
# Epoch 31/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -239.3424 - loss: -239.3424 - mean_particle_number: 2.6883
# Epoch 32/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -243.5280 - loss: -243.5280 - mean_particle_number: 2.6891
# Epoch 33/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -250.1330 - loss: -250.1330 - mean_particle_number: 2.6937
# Epoch 34/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -253.6335 - loss: -253.6335 - mean_particle_number: 2.7034
# Epoch 35/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - energy: -258.2927 - loss: -258.2927 - mean_particle_number: 2.6955
# Epoch 36/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - energy: -255.2501 - loss: -255.2501 - mean_particle_number: 2.7029
# Epoch 37/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -249.2873 - loss: -249.2873 - mean_particle_number: 2.7138
# Epoch 38/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -250.1919 - loss: -250.1919 - mean_particle_number: 2.7078
# Epoch 39/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -253.9957 - loss: -253.9957 - mean_particle_number: 2.6920
# Epoch 40/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -248.0078 - loss: -248.0078 - mean_particle_number: 2.7133
# Epoch 41/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -254.2560 - loss: -254.2560 - mean_particle_number: 2.7271
# Epoch 42/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -246.5832 - loss: -246.5832 - mean_particle_number: 2.7127
# Epoch 43/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -249.2605 - loss: -249.2605 - mean_particle_number: 2.7116
# Epoch 44/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -228.7354 - loss: -228.7354 - mean_particle_number: 2.7232
# Epoch 45/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -258.2825 - loss: -258.2825 - mean_particle_number: 2.7337
# Epoch 46/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -249.4383 - loss: -249.4383 - mean_particle_number: 2.7138
# Epoch 47/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -235.8601 - loss: -235.8601 - mean_particle_number: 2.7393
# Epoch 48/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -265.7482 - loss: -265.7482 - mean_particle_number: 2.7235
# Epoch 49/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -219.4451 - loss: -219.4451 - mean_particle_number: 2.7308
# Epoch 50/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -262.9836 - loss: -262.9836 - mean_particle_number: 2.7412
# Epoch 51/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -231.9898 - loss: -231.9898 - mean_particle_number: 2.7437
# Epoch 52/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -252.1550 - loss: -252.1550 - mean_particle_number: 2.7600
# Epoch 53/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -251.4554 - loss: -251.4554 - mean_particle_number: 2.7276
# Epoch 54/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -158.5929 - loss: -158.5929 - mean_particle_number: 2.7494
# Epoch 55/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - energy: -238.4888 - loss: -238.4888 - mean_particle_number: 2.7615
# Epoch 56/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - energy: -186.2441 - loss: -186.2441 - mean_particle_number: 2.7367
# Epoch 57/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -248.5825 - loss: -248.5825 - mean_particle_number: 2.7585
# Epoch 58/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -245.6942 - loss: -245.6942 - mean_particle_number: 2.7608
# Epoch 59/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -258.2676 - loss: -258.2676 - mean_particle_number: 2.7660
# Epoch 60/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -265.6299 - loss: -265.6299 - mean_particle_number: 2.7697
# Epoch 61/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -253.5677 - loss: -253.5677 - mean_particle_number: 2.7636
# Epoch 62/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -242.3885 - loss: -242.3885 - mean_particle_number: 2.7648
# Epoch 63/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -245.3006 - loss: -245.3006 - mean_particle_number: 2.7787
# Epoch 64/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -243.3212 - loss: -243.3212 - mean_particle_number: 2.7823
# Epoch 65/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -232.6475 - loss: -232.6475 - mean_particle_number: 2.7908
# Epoch 66/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -251.6349 - loss: -251.6349 - mean_particle_number: 2.7730
# Epoch 67/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -231.2694 - loss: -231.2694 - mean_particle_number: 2.7639
# Epoch 68/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -260.0593 - loss: -260.0593 - mean_particle_number: 2.7868
# Epoch 69/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -251.0484 - loss: -251.0484 - mean_particle_number: 2.7800
# Epoch 70/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -270.6876 - loss: -270.6876 - mean_particle_number: 2.8054
# Epoch 71/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -252.4062 - loss: -252.4062 - mean_particle_number: 2.8030
# Epoch 72/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -254.1144 - loss: -254.1144 - mean_particle_number: 2.7670
# Epoch 73/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -237.8323 - loss: -237.8323 - mean_particle_number: 2.8025
# Epoch 74/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -271.7925 - loss: -271.7925 - mean_particle_number: 2.8155
# Epoch 75/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -265.2665 - loss: -265.2665 - mean_particle_number: 2.8078
# Epoch 76/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -261.6913 - loss: -261.6913 - mean_particle_number: 2.8061
# Epoch 77/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -261.2370 - loss: -261.2370 - mean_particle_number: 2.7951
# Epoch 78/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -252.7416 - loss: -252.7416 - mean_particle_number: 2.8290
# Epoch 79/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -252.9330 - loss: -252.9330 - mean_particle_number: 2.8145
# Epoch 80/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -251.4142 - loss: -251.4142 - mean_particle_number: 2.8485
# Epoch 81/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -233.2770 - loss: -233.2770 - mean_particle_number: 2.8212
# Epoch 82/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - energy: -275.1026 - loss: -275.1026 - mean_particle_number: 2.8539
# Epoch 83/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -247.5221 - loss: -247.5221 - mean_particle_number: 2.8365
# Epoch 84/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -258.3908 - loss: -258.3908 - mean_particle_number: 2.8124
# Epoch 85/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -237.8299 - loss: -237.8299 - mean_particle_number: 2.8456
# Epoch 86/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -245.8679 - loss: -245.8679 - mean_particle_number: 2.8443
# Epoch 87/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -241.4139 - loss: -241.4139 - mean_particle_number: 2.8701
# Epoch 88/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - energy: -257.0656 - loss: -257.0656 - mean_particle_number: 2.8558
# Epoch 89/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - energy: -264.0346 - loss: -264.0346 - mean_particle_number: 2.8400
# Epoch 90/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -218.5853 - loss: -218.5853 - mean_particle_number: 2.8405
# Epoch 91/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -241.8195 - loss: -241.8195 - mean_particle_number: 2.8500
# Epoch 92/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -251.5695 - loss: -251.5695 - mean_particle_number: 2.8681
# Epoch 93/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -265.0424 - loss: -265.0424 - mean_particle_number: 2.8880
# Epoch 94/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -260.8604 - loss: -260.8604 - mean_particle_number: 2.8668
# Epoch 95/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -222.4049 - loss: -222.4049 - mean_particle_number: 2.8821
# Epoch 96/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -253.4230 - loss: -253.4230 - mean_particle_number: 2.8657
# Epoch 97/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -234.8726 - loss: -234.8726 - mean_particle_number: 2.8801
# Epoch 98/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -251.0322 - loss: -251.0322 - mean_particle_number: 2.8914
# Epoch 99/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -253.6196 - loss: -253.6196 - mean_particle_number: 2.8997
# Epoch 100/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -234.6674 - loss: -234.6674 - mean_particle_number: 2.8860
# Epoch 101/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -224.6106 - loss: -224.6106 - mean_particle_number: 2.8862
# Epoch 102/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -244.1530 - loss: -244.1530 - mean_particle_number: 2.8846
# Epoch 103/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -265.1487 - loss: -265.1487 - mean_particle_number: 2.8999
# Epoch 104/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -249.8932 - loss: -249.8932 - mean_particle_number: 2.8977
# Epoch 105/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -254.8796 - loss: -254.8796 - mean_particle_number: 2.9134
# Epoch 106/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -263.1164 - loss: -263.1164 - mean_particle_number: 2.9117
# Epoch 107/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -243.9296 - loss: -243.9296 - mean_particle_number: 2.9225
# Epoch 108/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -257.7789 - loss: -257.7789 - mean_particle_number: 2.9139
# Epoch 109/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -257.0895 - loss: -257.0895 - mean_particle_number: 2.9190
# Epoch 110/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -225.1920 - loss: -225.1920 - mean_particle_number: 2.9216
# Epoch 111/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -242.0108 - loss: -242.0108 - mean_particle_number: 2.9377
# Epoch 112/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -245.5947 - loss: -245.5947 - mean_particle_number: 2.9266
# Epoch 113/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -255.1151 - loss: -255.1151 - mean_particle_number: 2.9261
# Epoch 114/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -254.2404 - loss: -254.2404 - mean_particle_number: 2.9387
# Epoch 115/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -251.7724 - loss: -251.7724 - mean_particle_number: 2.9406
# Epoch 116/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -238.1890 - loss: -238.1890 - mean_particle_number: 2.9604
# Epoch 117/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -269.6546 - loss: -269.6546 - mean_particle_number: 2.9375
# Epoch 118/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -176.2875 - loss: -176.2875 - mean_particle_number: 2.9432
# Epoch 119/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - energy: -242.9872 - loss: -242.9872 - mean_particle_number: 2.9565
# Epoch 120/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -263.2174 - loss: -263.2174 - mean_particle_number: 2.9427
# Epoch 121/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -266.1921 - loss: -266.1921 - mean_particle_number: 2.9601
# Epoch 122/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -251.9750 - loss: -251.9750 - mean_particle_number: 2.9631
# Epoch 123/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -262.1950 - loss: -262.1950 - mean_particle_number: 2.9527
# Epoch 124/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -263.8717 - loss: -263.8717 - mean_particle_number: 2.9576
# Epoch 125/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -255.0711 - loss: -255.0711 - mean_particle_number: 2.9567
# Epoch 126/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -226.4577 - loss: -226.4577 - mean_particle_number: 2.9782
# Epoch 127/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -211.9320 - loss: -211.9320 - mean_particle_number: 2.9404
# Epoch 128/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -259.5611 - loss: -259.5611 - mean_particle_number: 2.9645
# Epoch 129/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -260.1483 - loss: -260.1483 - mean_particle_number: 2.9576
# Epoch 130/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -256.5366 - loss: -256.5366 - mean_particle_number: 2.9904
# Epoch 131/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -261.0339 - loss: -261.0339 - mean_particle_number: 2.9712
# Epoch 132/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -208.6950 - loss: -208.6950 - mean_particle_number: 2.9742
# Epoch 133/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -238.1673 - loss: -238.1673 - mean_particle_number: 2.9924
# Epoch 134/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -259.7407 - loss: -259.7407 - mean_particle_number: 2.9794
# Epoch 135/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - energy: -270.1077 - loss: -270.1077 - mean_particle_number: 2.9892
# Epoch 136/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -253.5872 - loss: -253.5872 - mean_particle_number: 2.9944
# Epoch 137/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -253.5044 - loss: -253.5044 - mean_particle_number: 2.9778
# Epoch 138/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -269.0138 - loss: -269.0138 - mean_particle_number: 2.9811
# Epoch 139/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -256.7414 - loss: -256.7414 - mean_particle_number: 3.0170
# Epoch 140/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - energy: -257.2876 - loss: -257.2876 - mean_particle_number: 3.0148
# Epoch 141/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -267.8627 - loss: -267.8627 - mean_particle_number: 2.9975
# Epoch 142/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - energy: -251.9755 - loss: -251.9755 - mean_particle_number: 3.0213
# Epoch 143/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -260.6229 - loss: -260.6229 - mean_particle_number: 3.0042
# Epoch 144/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -266.5740 - loss: -266.5740 - mean_particle_number: 3.0124
# Epoch 145/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -212.3574 - loss: -212.3574 - mean_particle_number: 3.0003
# Epoch 146/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -265.2482 - loss: -265.2482 - mean_particle_number: 3.0175
# Epoch 147/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -257.0899 - loss: -257.0899 - mean_particle_number: 3.0175
# Epoch 148/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -258.6341 - loss: -258.6341 - mean_particle_number: 3.0255
# Epoch 149/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -233.4463 - loss: -233.4463 - mean_particle_number: 3.0339
# Epoch 150/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -268.1106 - loss: -268.1106 - mean_particle_number: 3.0317
# Epoch 151/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -259.5965 - loss: -259.5965 - mean_particle_number: 3.0236
# Epoch 152/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -254.6267 - loss: -254.6267 - mean_particle_number: 3.0240
# Epoch 153/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -252.9795 - loss: -252.9795 - mean_particle_number: 3.0391
# Epoch 154/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -244.0359 - loss: -244.0359 - mean_particle_number: 3.0228
# Epoch 155/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -271.4991 - loss: -271.4991 - mean_particle_number: 3.0251
# Epoch 156/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - energy: -247.5943 - loss: -247.5943 - mean_particle_number: 3.0535
# Epoch 157/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -245.5523 - loss: -245.5523 - mean_particle_number: 3.0319
# Epoch 158/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -249.9697 - loss: -249.9697 - mean_particle_number: 3.0372
# Epoch 159/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -211.5449 - loss: -211.5449 - mean_particle_number: 3.0572
# Epoch 160/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -240.6246 - loss: -240.6246 - mean_particle_number: 3.0209
# Epoch 161/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -255.1626 - loss: -255.1626 - mean_particle_number: 3.0325
# Epoch 162/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -257.9358 - loss: -257.9358 - mean_particle_number: 3.0502
# Epoch 163/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -263.1134 - loss: -263.1134 - mean_particle_number: 3.0612
# Epoch 164/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -250.6467 - loss: -250.6467 - mean_particle_number: 3.0532
# Epoch 165/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -256.2614 - loss: -256.2614 - mean_particle_number: 3.0549
# Epoch 166/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -273.0022 - loss: -273.0022 - mean_particle_number: 3.0518
# Epoch 167/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -231.4860 - loss: -231.4860 - mean_particle_number: 3.0684
# Epoch 168/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -272.5754 - loss: -272.5754 - mean_particle_number: 3.0570
# Epoch 169/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -253.6306 - loss: -253.6306 - mean_particle_number: 3.0637
# Epoch 170/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - energy: -237.6530 - loss: -237.6530 - mean_particle_number: 3.0589
# Epoch 171/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - energy: -258.6285 - loss: -258.6285 - mean_particle_number: 3.0597
# Epoch 172/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -239.5529 - loss: -239.5529 - mean_particle_number: 3.0618
# Epoch 173/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - energy: -250.0750 - loss: -250.0750 - mean_particle_number: 3.0687
# Epoch 174/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -262.6521 - loss: -262.6521 - mean_particle_number: 3.0608
# Epoch 175/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -260.8594 - loss: -260.8594 - mean_particle_number: 3.0786
# Epoch 176/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -257.6351 - loss: -257.6351 - mean_particle_number: 3.0957
# Epoch 177/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -251.4895 - loss: -251.4895 - mean_particle_number: 3.0978
# Epoch 178/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -251.1251 - loss: -251.1251 - mean_particle_number: 3.0712
# Epoch 179/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -257.2302 - loss: -257.2302 - mean_particle_number: 3.0791
# Epoch 180/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -274.6263 - loss: -274.6263 - mean_particle_number: 3.0769
# Epoch 181/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -237.7388 - loss: -237.7388 - mean_particle_number: 3.0733
# Epoch 182/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 28s 20ms/step - energy: -251.7344 - loss: -251.7344 - mean_particle_number: 3.0786
# Epoch 183/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 27s 19ms/step - energy: -261.8267 - loss: -261.8267 - mean_particle_number: 3.0809
# Epoch 184/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -257.0001 - loss: -257.0001 - mean_particle_number: 3.0764
# Epoch 185/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - energy: -249.5439 - loss: -249.5439 - mean_particle_number: 3.0733
# Epoch 186/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -266.1593 - loss: -266.1593 - mean_particle_number: 3.0909
# Epoch 187/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -275.7817 - loss: -275.7817 - mean_particle_number: 3.0862
# Epoch 188/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - energy: -252.6460 - loss: -252.6460 - mean_particle_number: 3.0750
# Epoch 189/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - energy: -253.1365 - loss: -253.1365 - mean_particle_number: 3.0979
# Epoch 190/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -232.3369 - loss: -232.3369 - mean_particle_number: 3.0987
# Epoch 191/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - energy: -260.2792 - loss: -260.2792 - mean_particle_number: 3.0989
# Epoch 192/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -202.7903 - loss: -202.7903 - mean_particle_number: 3.1185
# Epoch 193/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - energy: -256.2031 - loss: -256.2031 - mean_particle_number: 3.1018
# Epoch 194/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - energy: -242.4519 - loss: -242.4519 - mean_particle_number: 3.1007
# Epoch 195/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 27s 20ms/step - energy: -229.5438 - loss: -229.5438 - mean_particle_number: 3.1214
# Epoch 196/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -242.4156 - loss: -242.4156 - mean_particle_number: 3.0816
# Epoch 197/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - energy: -222.6387 - loss: -222.6387 - mean_particle_number: 3.0920
# Epoch 198/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -205.4595 - loss: -205.4595 - mean_particle_number: 3.0858
# Epoch 199/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -266.5837 - loss: -266.5837 - mean_particle_number: 3.1317
# Epoch 200/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -263.5197 - loss: -263.5197 - mean_particle_number: 3.1011
# Epoch 201/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -249.3661 - loss: -249.3661 - mean_particle_number: 3.1074
# Epoch 202/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -255.5558 - loss: -255.5558 - mean_particle_number: 3.0916
# Epoch 203/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -245.5305 - loss: -245.5305 - mean_particle_number: 3.1088
# Epoch 204/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -122.7736 - loss: -122.7736 - mean_particle_number: 3.1054
# Epoch 205/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -250.3800 - loss: -250.3800 - mean_particle_number: 3.1091
# Epoch 206/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -261.0315 - loss: -261.0315 - mean_particle_number: 3.1128
# Epoch 207/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -250.1425 - loss: -250.1425 - mean_particle_number: 3.1013
# Epoch 208/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -259.1631 - loss: -259.1631 - mean_particle_number: 3.1145
# Epoch 209/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -260.5778 - loss: -260.5778 - mean_particle_number: 3.1133
# Epoch 210/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -234.6011 - loss: -234.6011 - mean_particle_number: 3.0995
# Epoch 211/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -262.4127 - loss: -262.4127 - mean_particle_number: 3.1074
# Epoch 212/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -246.7244 - loss: -246.7244 - mean_particle_number: 3.1015
# Epoch 213/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -245.6843 - loss: -245.6843 - mean_particle_number: 3.1323
# Epoch 214/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -240.5000 - loss: -240.5000 - mean_particle_number: 3.1133
# Epoch 215/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - energy: -233.6582 - loss: -233.6582 - mean_particle_number: 3.1033
# Epoch 216/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -280.4034 - loss: -280.4034 - mean_particle_number: 3.1442
# Epoch 217/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -245.4429 - loss: -245.4429 - mean_particle_number: 3.1149
# Epoch 218/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -200.0322 - loss: -200.0322 - mean_particle_number: 3.1114
# Epoch 219/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -245.0740 - loss: -245.0740 - mean_particle_number: 3.1283
# Epoch 220/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -231.4529 - loss: -231.4529 - mean_particle_number: 3.1207
# Epoch 221/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -250.1641 - loss: -250.1641 - mean_particle_number: 3.1291
# Epoch 222/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -258.2265 - loss: -258.2265 - mean_particle_number: 3.1227
# Epoch 223/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -267.8695 - loss: -267.8695 - mean_particle_number: 3.1292
# Epoch 224/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: 1320.5358 - loss: 1320.5358 - mean_particle_number: 3.1159
# Epoch 225/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -244.7035 - loss: -244.7035 - mean_particle_number: 3.1284
# Epoch 226/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -240.0622 - loss: -240.0622 - mean_particle_number: 3.1407
# Epoch 227/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -239.1102 - loss: -239.1102 - mean_particle_number: 3.1401
# Epoch 228/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -262.6148 - loss: -262.6148 - mean_particle_number: 3.1298
# Epoch 229/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - energy: -246.8046 - loss: -246.8046 - mean_particle_number: 3.1388
# Epoch 230/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - energy: -252.7757 - loss: -252.7757 - mean_particle_number: 3.1354
# Epoch 231/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -229.3703 - loss: -229.3703 - mean_particle_number: 3.1358
# Epoch 232/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -246.1852 - loss: -246.1852 - mean_particle_number: 3.1363
# Epoch 233/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -245.0644 - loss: -245.0644 - mean_particle_number: 3.1382
# Epoch 234/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - energy: -230.2733 - loss: -230.2733 - mean_particle_number: 3.1195
# Epoch 235/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - energy: -242.9696 - loss: -242.9696 - mean_particle_number: 3.1491
# Epoch 236/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -247.7146 - loss: -247.7146 - mean_particle_number: 3.1331
# Epoch 237/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -127.8020 - loss: -127.8020 - mean_particle_number: 3.1362
# Epoch 238/500
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -256.0522 - loss: -256.0522 - mean_particle_number: 3.1176
# Epoch 239/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 13
#       1 lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#       2     1e-2,
#       3     decay_steps = 50,
#       4     decay_rate = 0.9,
#       5     staircase=True
#       6 )
#       8 test_model.compile(
#       9     optimizer = tf.keras.optimizers.Adam(lr_schedule),
#      10     regularization_lr_modifier = 100
#      11 )
# ---> 13 history = test_model.fit(
#      14     dataset.skip(500).take(1000),
#      15     epochs = 500,
#      16 )
#
# File c:\Users\marcr\Documents\vs_code\nn_qft\modules\ansatz_nn.py:229, in QFTNeuralNet.fit(self, *args, **kwargs)
#     225 callbacks.append(ApplyGradientCallback())
#     227 kwargs['callbacks'] = callbacks
# --> 229 return super().fit(*args, **kwargs)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
fig, axes = plots.plot_train_history(test_model.history, -278.2, 3)

# %%
fig, axes = plots.plot_metropolis_samples(dataset.skip(500).unbatch().take(7000));

# %% [markdown]
# ## Lieb-Liniger, with $m = 0.5$, $\mu = (8.75 \pi)^2$, $g = 10^6$

# %%
input_dim = 1
batch_size = 64

ds1 = ansatz_nn.DeepSets(64, 4, 4, input_dim=input_dim, name = "deep_set_1")
ds2 = ansatz_nn.DeepSets(64, 4, 4, input_dim=input_dim, name = "deep_set_2")

hamiltonian = ll_model.LiebLinigerHamiltonian(0.5, (8.75 * np.pi) ** 2, 1e6)

test_model = ansatz_nn.QFTNeuralNet(
    np.array([1]),
    ds1,
    ds2,
    hamiltonian,
    is_periodic = False,
    regularization = ParticleNoReg(8, 0.2, 0.3)
)

dataset = metro.make_dataset(test_model, batch_size, 10, 5)

# %%
tfds.benchmark(dataset.take(1000), batch_size = batch_size)
# Out:
# ************ Summary ************
# 0it [00:00, ?it/s]
# Examples/sec (First included) 3651.53 ex/sec (total: 64064 ex, 17.54 sec)
# Examples/sec (First only) 597.24 ex/sec (total: 64 ex, 0.11 sec)
# Examples/sec (First excluded) 3670.30 ex/sec (total: 64000 ex, 17.44 sec)
# BenchmarkResult(stats=              duration  num_examples          avg
# first+lasts  17.544438         64064  3651.527686
# first         0.107160            64   597.236103
# lasts        17.437277         64000  3670.297750, raw_stats=                      duration
# start_time        42627.312728
# first_batch_time  42627.419888
# end_time          42644.857165
# num_iter           1000.000000)

# %%
fig, axes = plots.plot_metropolis_samples(dataset.skip(500).unbatch().take(7000));

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    1e-1,
    decay_steps = 25,
    decay_rate = 0.9,
    staircase=True
)

test_model.compile(
    optimizer = tf.keras.optimizers.Adam(lr_schedule),
    regularization_lr_modifier = 100
)

history = test_model.fit(
    dataset.skip(500).take(1000),
    epochs = 200,
)
# Out:
# Epoch 1/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - energy: -4234.5454 - loss: -4234.5454 - mean_particle_number: 5.8053
# Epoch 2/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 28s 20ms/step - energy: -3207.4548 - loss: -3207.4548 - mean_particle_number: 6.1312
# Epoch 3/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 27s 19ms/step - energy: -3038.6565 - loss: -3038.6565 - mean_particle_number: 6.0583
# Epoch 4/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -3367.4316 - loss: -3367.4316 - mean_particle_number: 5.9550
# Epoch 5/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -3389.5173 - loss: -3389.5173 - mean_particle_number: 5.9055
# Epoch 6/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -3296.2478 - loss: -3296.2478 - mean_particle_number: 5.8671
# Epoch 7/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -2849.5129 - loss: -2849.5129 - mean_particle_number: 5.7918
# Epoch 8/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -3251.0491 - loss: -3251.0491 - mean_particle_number: 5.7486
# Epoch 9/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -3398.0200 - loss: -3398.0200 - mean_particle_number: 5.6063
# Epoch 10/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -3367.6309 - loss: -3367.6309 - mean_particle_number: 5.5799
# Epoch 11/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -3170.2166 - loss: -3170.2166 - mean_particle_number: 5.5736
# Epoch 12/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -3265.6511 - loss: -3265.6511 - mean_particle_number: 5.5026
# Epoch 13/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -3206.9338 - loss: -3206.9338 - mean_particle_number: 5.4366
# Epoch 14/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - energy: -3244.2649 - loss: -3244.2649 - mean_particle_number: 5.3577
# Epoch 15/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 27s 19ms/step - energy: -3198.3989 - loss: -3198.3989 - mean_particle_number: 5.3163
# Epoch 16/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 26s 19ms/step - energy: -3158.3547 - loss: -3158.3547 - mean_particle_number: 5.2703
# Epoch 17/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 13
#       1 lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#       2     1e-1,
#       3     decay_steps = 25,
#       4     decay_rate = 0.9,
#       5     staircase=True
#       6 )
#       8 test_model.compile(
#       9     optimizer = tf.keras.optimizers.Adam(lr_schedule),
#      10     regularization_lr_modifier = 100
#      11 )
# ---> 13 history = test_model.fit(
#      14     dataset.skip(500).take(1000),
#      15     epochs = 200,
#      16 )
#
# File c:\Users\marcr\Documents\vs_code\nn_qft\modules\ansatz_nn.py:229, in QFTNeuralNet.fit(self, *args, **kwargs)
#     225 callbacks.append(ApplyGradientCallback())
#     227 kwargs['callbacks'] = callbacks
# --> 229 return super().fit(*args, **kwargs)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
fig, axes = plots.plot_train_history(test_model.history, -4031.79, 8)

# %%
fig, axes = plots.plot_metropolis_samples(dataset.skip(500).unbatch().take(7000));

# %% [markdown]
# ## Lieb-Liniger, with $m = 0.5$, $\mu = 185$, $g = 10$

# %%
input_dim = 1
batch_size = 64

ds1 = ansatz_nn.DeepSets(64, 2, 2, input_dim=input_dim, name = "deep_set_1")
ds2 = ansatz_nn.DeepSets(64, 2, 2, input_dim=input_dim, name = "deep_set_2")

hamiltonian = ll_model.LiebLinigerHamiltonian(0.5, 185, 10)

test_model = ansatz_nn.QFTNeuralNet(
    np.array([1]),
    ds1,
    ds2,
    hamiltonian,
    is_periodic = False
)

dataset = metro.make_dataset(test_model, batch_size, 15, 5)

# %%
tfds.benchmark(dataset.take(1000), batch_size = batch_size)
# Out:
# ************ Summary ************
# 0it [00:00, ?it/s]
# Examples/sec (First included) 5421.28 ex/sec (total: 64064 ex, 11.82 sec)
# Examples/sec (First only) 768.48 ex/sec (total: 64 ex, 0.08 sec)
# Examples/sec (First excluded) 5454.30 ex/sec (total: 64000 ex, 11.73 sec)
# BenchmarkResult(stats=              duration  num_examples          avg
# first+lasts  11.817137         64064  5421.279466
# first         0.083282            64   768.475225
# lasts        11.733855         64000  5454.303048, raw_stats=                      duration
# start_time        41498.104192
# first_batch_time  41498.187474
# end_time          41509.921328
# num_iter           1000.000000)

# %%
fig, axes = plots.plot_metropolis_samples(dataset.skip(500).unbatch().take(7000));

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    1e-2,
    decay_steps = 50,
    decay_rate = 0.9,
    staircase=True
)

test_model.compile(
    optimizer = tf.keras.optimizers.Adam(lr_schedule),
    regularization_lr_modifier = 100
)

history = test_model.fit(
    dataset.skip(500).take(1000),
    epochs = 200,
)
# Out:
# Epoch 1/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - energy: -187.0140 - loss: -187.0140 - mean_particle_number: 1.0762
# Epoch 2/200
# c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - energy: -205.6498 - loss: -205.6498 - mean_particle_number: 1.1890
# Epoch 3/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -244.7651 - loss: -244.7651 - mean_particle_number: 1.4408
# Epoch 4/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -302.0182 - loss: -302.0182 - mean_particle_number: 1.8598
# Epoch 5/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -350.1916 - loss: -350.1916 - mean_particle_number: 2.1812
# Epoch 6/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -375.1066 - loss: -375.1066 - mean_particle_number: 2.3255
# Epoch 7/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -392.5240 - loss: -392.5240 - mean_particle_number: 2.4015
# Epoch 8/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -394.4621 - loss: -394.4621 - mean_particle_number: 2.4051
# Epoch 9/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -400.1051 - loss: -400.1051 - mean_particle_number: 2.4418
# Epoch 10/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -408.1166 - loss: -408.1166 - mean_particle_number: 2.4561
# Epoch 11/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -384.5638 - loss: -384.5638 - mean_particle_number: 2.4608
# Epoch 12/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -399.5088 - loss: -399.5088 - mean_particle_number: 2.4696
# Epoch 13/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - energy: -405.9096 - loss: -405.9096 - mean_particle_number: 2.4819
# Epoch 14/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -405.4798 - loss: -405.4798 - mean_particle_number: 2.4852
# Epoch 15/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -403.5605 - loss: -403.5605 - mean_particle_number: 2.4761
# Epoch 16/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -404.7045 - loss: -404.7045 - mean_particle_number: 2.4788
# Epoch 17/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -414.5691 - loss: -414.5691 - mean_particle_number: 2.4886
# Epoch 18/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -407.1735 - loss: -407.1735 - mean_particle_number: 2.4823
# Epoch 19/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -388.2092 - loss: -388.2092 - mean_particle_number: 2.4896
# Epoch 20/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -407.9986 - loss: -407.9986 - mean_particle_number: 2.4905
# Epoch 21/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -411.5349 - loss: -411.5349 - mean_particle_number: 2.4881
# Epoch 22/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -405.5454 - loss: -405.5454 - mean_particle_number: 2.4897
# Epoch 23/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -409.4492 - loss: -409.4492 - mean_particle_number: 2.4833
# Epoch 24/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -402.1169 - loss: -402.1169 - mean_particle_number: 2.4708
# Epoch 25/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -400.2591 - loss: -400.2591 - mean_particle_number: 2.4965
# Epoch 26/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -411.4100 - loss: -411.4100 - mean_particle_number: 2.4814
# Epoch 27/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -407.1336 - loss: -407.1336 - mean_particle_number: 2.4798
# Epoch 28/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -402.5663 - loss: -402.5663 - mean_particle_number: 2.4918
# Epoch 29/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -413.7201 - loss: -413.7201 - mean_particle_number: 2.4858
# Epoch 30/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -404.2072 - loss: -404.2072 - mean_particle_number: 2.4791
# Epoch 31/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -406.5903 - loss: -406.5903 - mean_particle_number: 2.4841
# Epoch 32/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -401.9284 - loss: -401.9284 - mean_particle_number: 2.4910
# Epoch 33/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -400.2765 - loss: -400.2765 - mean_particle_number: 2.4761
# Epoch 34/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -412.0493 - loss: -412.0493 - mean_particle_number: 2.4784
# Epoch 35/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -405.8337 - loss: -405.8337 - mean_particle_number: 2.4759
# Epoch 36/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -415.2168 - loss: -415.2168 - mean_particle_number: 2.4832
# Epoch 37/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -411.3365 - loss: -411.3365 - mean_particle_number: 2.4762
# Epoch 38/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -417.4249 - loss: -417.4249 - mean_particle_number: 2.4954
# Epoch 39/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -413.3819 - loss: -413.3819 - mean_particle_number: 2.4878
# Epoch 40/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -409.9261 - loss: -409.9261 - mean_particle_number: 2.4787
# Epoch 41/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -406.4256 - loss: -406.4256 - mean_particle_number: 2.4771
# Epoch 42/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - energy: -414.0751 - loss: -414.0751 - mean_particle_number: 2.4976
# Epoch 43/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -413.1238 - loss: -413.1238 - mean_particle_number: 2.4982
# Epoch 44/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -410.6049 - loss: -410.6049 - mean_particle_number: 2.4850
# Epoch 45/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - energy: -408.6872 - loss: -408.6872 - mean_particle_number: 2.4817
# Epoch 46/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - energy: -411.0477 - loss: -411.0477 - mean_particle_number: 2.4793
# Epoch 47/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -412.1251 - loss: -412.1251 - mean_particle_number: 2.4951
# Epoch 48/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -412.8640 - loss: -412.8640 - mean_particle_number: 2.4878
# Epoch 49/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -413.9636 - loss: -413.9636 - mean_particle_number: 2.4935
# Epoch 50/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -409.5824 - loss: -409.5824 - mean_particle_number: 2.4845
# Epoch 51/200
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - energy: -416.0158 - loss: -416.0158 - mean_particle_number: 2.5006
# Epoch 52/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 13
#       1 lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#       2     1e-2,
#       3     decay_steps = 50,
#       4     decay_rate = 0.9,
#       5     staircase=True
#       6 )
#       8 test_model.compile(
#       9     optimizer = tf.keras.optimizers.Adam(lr_schedule),
#      10     regularization_lr_modifier = 100
#      11 )
# ---> 13 history = test_model.fit(
#      14     dataset.skip(500).take(1000),
#      15     epochs = 200,
#      16 )
#
# File c:\Users\marcr\Documents\vs_code\nn_qft\modules\ansatz_nn.py:229, in QFTNeuralNet.fit(self, *args, **kwargs)
#     225 callbacks.append(ApplyGradientCallback())
#     227 kwargs['callbacks'] = callbacks
# --> 229 return super().fit(*args, **kwargs)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\marcr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
fig, axes = plots.plot_train_history(test_model.history, -954.6, 10)

# %%
fig, axes = plots.plot_metropolis_samples(dataset.skip(500).unbatch().take(7000));
